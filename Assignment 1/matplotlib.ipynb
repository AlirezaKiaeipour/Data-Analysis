# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1, 8])
y = np.array([3, 10])
plt.plot(x,y)

# %%
plt.plot(x,y,"o")

# %%
x = np.array([1, 2, 6, 8])
y = np.array([3, 8, 1, 10])
plt.plot(x,y,marker="o")

# %%
y = np.array([3, 8, 1, 10, 5, 7])
plt.plot(y,marker="o")

# %%
plt.plot(y,"o:r")

# %%
plt.plot(y,marker="o",ms=10,mec="red")

# %%
plt.plot(y,marker="o",ms=10,mfc="red")

# %%
plt.plot(y,marker="o",ms=10,mec="yellow",mfc="yellow")

# %%
plt.plot(y,linestyle="dotted")

# %%
plt.plot(y,linestyle="dashed")

# %%
plt.plot(y,c="red")

# %%
plt.plot(y,linestyle="dashed",linewidth=10)

# %%
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])
plt.plot(y1)
plt.plot(y2)

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])
plt.plot(x1,y1,x2,y2)
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.xlabel("X",fontdict=font2)
plt.ylabel("Y",fontdict=font2)
plt.title("Line plot chart",fontdict=font1)
plt.grid(color="red",linewidth=0.5,linestyle="dashed")

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])
plt.plot(x1,y1,x2,y2)
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.xlabel("X",fontdict=font2)
plt.ylabel("Y",fontdict=font2)
plt.title("Line plot chart",fontdict=font1)
plt.grid(axis="x")

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])
plt.plot(x1,y1,x2,y2)
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.xlabel("X",fontdict=font2)
plt.ylabel("Y",fontdict=font2)
plt.title("Line plot chart",fontdict=font1)
plt.grid(axis="y")

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(1,2,1)
plt.plot(x)
plt.plot(y)

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(2,1,1)
plt.plot(x,y)
plt.title("chart 1")
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(2,1,2)
plt.title("chart 2")
plt.plot(x,y)
plt.suptitle("chart")
# Out:
# Text(0.5, 0.98, 'chart')

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y,c="red")
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x,y,c="purple")

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])
plt.scatter(x,y,c=colors)
plt.colorbar()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
plt.scatter(x,y,s=sizes,alpha=0.5)

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.bar(x,y,width=0.2)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(x,y,color="red",height=0.2)
# Out:
# <BarContainer object of 4 artists>

# %%
x = np.random.normal(170, 10, 250)
plt.hist(x,bins=50)
# Out:
# (array([ 1.,  0.,  0.,  0.,  1.,  1.,  2.,  2.,  3.,  3.,  2.,  5.,  6.,
#          4.,  5., 11., 10.,  7.,  8.,  8., 13., 10., 13., 16.,  9., 14.,
#          8., 19.,  9.,  7., 10.,  7.,  6.,  4.,  3.,  4.,  5.,  4.,  0.,
#          0.,  2.,  4.,  0.,  0.,  1.,  0.,  2.,  0.,  0.,  1.]),
#  array([143.19479865, 144.35539913, 145.5159996 , 146.67660008,
#         147.83720056, 148.99780104, 150.15840152, 151.31900199,
#         152.47960247, 153.64020295, 154.80080343, 155.9614039 ,
#         157.12200438, 158.28260486, 159.44320534, 160.60380581,
#         161.76440629, 162.92500677, 164.08560725, 165.24620772,
#         166.4068082 , 167.56740868, 168.72800916, 169.88860963,
#         171.04921011, 172.20981059, 173.37041107, 174.53101155,
#         175.69161202, 176.8522125 , 178.01281298, 179.17341346,
#         180.33401393, 181.49461441, 182.65521489, 183.81581537,
#         184.97641584, 186.13701632, 187.2976168 , 188.45821728,
# ...

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(y,labels=mylabels)
# Out:
# ([<matplotlib.patches.Wedge at 0x2334a1b8100>,
# ...
#  [Text(0.4993895680663529, 0.9801071672559597, 'Apples'),
#   Text(-1.086457168210212, 0.17207795223283895, 'Bananas'),
#   Text(-0.172077952232839, -1.086457168210212, 'Cherries'),
#   Text(0.9801071672559598, -0.4993895680663526, 'Dates')])

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(y, labels = mylabels, startangle = 45)
# Out:
# ([<matplotlib.patches.Wedge at 0x233497cd880>,
# ...
#  [Text(-0.33991867422268773, 1.046162174289766, 'Apples'),
#   Text(-0.8899187180267097, -0.6465637441936393, 'Bananas'),
#   Text(0.6465637441936392, -0.8899187180267097, 'Cherries'),
#   Text(1.0461621742897658, 0.33991867422268807, 'Dates')])

# %%
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0, 0.2, 0, 0]
mycolors = ["black", "hotpink", "b", "#4CAF50"]
plt.pie(y,labels=mylabels,explode=myexplode,colors=mycolors)
plt.legend()
